# %%
import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

# %% [markdown]
# This is creating a table of interest in Taylor Swift by region.

# %%
pytrend.build_payload(kw_list=["Taylor Swift"])
# Interest by Region
df = pytrend.interest_by_region()
df.head(5)
# Out:
#                 Taylor Swift
# geoName
# Afghanistan                0
# Albania                    0
# Algeria                    0
# American Samoa             0
# Andorra                    0

# %% [markdown]
# This is creating a table of interest in Taylor Swift by region, no longer inclusing regions with no (0) interest

# %%
pytrend.build_payload(kw_list=["Taylor Swift"])
# Interest by Region
df = pytrend.interest_by_region()
nozero = (df != 0).any(axis=1)
clean_df = df.loc[nozero]
clean_df.head(5)
# Out:
#             Taylor Swift
# geoName
# Algeria               11
# Argentina             22
# Australia             62
# Austria               17
# Bangladesh            25

# %% [markdown]
# This is creating a bar chart of regional interest of Taylor Swift, excluding regions with no interest.

# %%
clean_df.reset_index().plot(x="geoName", y="Taylor Swift", figsize=(120, 10), kind ="bar")

# %% [markdown]
# This is creating a table of regions that have an interest over 50

# %%
pytrend.build_payload(kw_list=["Taylor Swift"])
# Interest by Region
df = pytrend.interest_by_region()
overfifty = (df > 50).any(axis=1)
large_df = df.loc[overfifty]
large_df.head(10)
# Out:
#                  Taylor Swift
# geoName
# Australia                  60
# Canada                     56
# Myanmar (Burma)            94
# New Zealand                55
# Philippines               100
# United States              62

# %% [markdown]
# This is creating a graph of interest in Taylor Swift in regions with over 50.

# %%
large_df.reset_index().plot(x="geoName", y="Taylor Swift", figsize=(120, 10), kind ="bar")

# %% [markdown]
# This is creating a table of interest in Taylor Swift for regions with an interest level over 30.

# %%
pytrend.build_payload(kw_list=["Taylor Swift"])
# Interest by Region
df = pytrend.interest_by_region()
overthirty = (df > 30).any(axis=1)
large_taylor = df.loc[overthirty]
large_taylor.head(15)
# Out:
#                  Taylor Swift
# geoName
# Australia                  59
# Canada                     54
# Hong Kong                  31
# Ireland                    49
# Malaysia                   39
# Myanmar (Burma)            90
# New Zealand                54
# Paraguay                   35
# Philippines               100
# Singapore                  49
# South Africa               40
# United Kingdom             36
# United States              63

# %% [markdown]
# This is creating a table of interest in Red Taylor Swift for regions with an interest level over 30.

# %%
pytrend.build_payload(kw_list=["Red Taylor Swift"])
# Interest by Region
df = pytrend.interest_by_region()
overthirty = (df > 30).any(axis=1)
large_red = df.loc[overthirty]
large_red.head(15)
# Out:
#                Red Taylor Swift
# geoName
# Canada                       32
# New Zealand                  34
# Philippines                 100
# Singapore                    36
# United States                36

# %% [markdown]
# This is creating a table of interest in Red (Taylor's Version) for regions with an interest level over 30.

# %%
pytrend.build_payload(kw_list=["Red (Taylor's Version)'"])
# Interest by Region
df = pytrend.interest_by_region()
overthirty = (df > 30).any(axis=1)
large_tv = df.loc[overthirty]
large_tv.head(15)
# Out:
#                Red (Taylor's Version)'
# geoName
# Australia                           44
# Honduras                           100
# Ireland                             46
# New Zealand                         44
# Paraguay                            37
# Philippines                         52
# Puerto Rico                         86
# United States                       35

# %% [markdown]
# These are the related queries for Taylor Swift, over all of time.

# %%
pytrend.build_payload(kw_list=["Taylor Swift"])
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                        query  value
# 0        taylor swift lyrics    100
# 1          taylor swift song     59
# 2            taylor swift me     56
# 3         taylor swift songs     49
# 4         taylor swift album     28
# 5         lover taylor swift     23
# 6                 reputation     22
# 7    taylor swift reputation     21
# 8               selena gomez     21
# 9          taylor swift tour     20
# 10                       red     18
# 11          taylor swift red     17
# 12   katy perry taylor swift     17
# 13                katy perry     17
# 14    taylor swift net worth     16
# 15      taylor swift youtube     16
# 16                 joe alwyn     16
# 17    taylor swift joe alwyn     16
# 18    taylor swift boyfriend     16
# 19                love story     16
# 20    taylor swift me lyrics     15
# 21   taylor swift love story     15
# 22    instagram taylor swift     15
# 23     taylor swift new song     13
# ...

# %% [markdown]
# This is gatheirng the related queries related to Taylor's Version.

# %%
pytrend.build_payload(kw_list=["Taylor's Version"])
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                                      query  value
# 0                      taylors version red    100
# 1                             taylor swift     56
# 2             taylor swift taylors version     55
# 3                 fearless taylors version     41
# 4               love story taylors version     12
# 5                  what is taylors version     11
# 6    taylor swift fearless taylors version     11
# 7             all too well taylors version     11
# 8                  taylors version meaning      9
# 9      all too well taylors version lyrics      8
# 10       love story taylors version lyrics      8
# 11   all too well 10 minute version lyrics      4
# 12          wildest dreams taylors version      4
# 13              red taylors version review      1
# 14                    1989 taylors version      1
# 15  love story taylors version differences      1
# ...

# %% [markdown]
# Releated searches about Taylor swift from November 2021, the month of the Red (Taylor's Version) release.

# %%
kw_list = ["Taylor Swift"]
pytrend.build_payload(kw_list, cat=0, timeframe='2021-11-01 2021-11-30', geo='', gprop='')
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                                     query  value
# 0                       jake taylor swift    100
# 1            jake gyllenhaal taylor swift     98
# 2                         jake gyllenhaal     95
# 3                     taylor swift lyrics     62
# 4               taylor swift all too well     50
# 5                        red taylor swift     50
# 6                                     red     49
# 7                            all too well     48
# 8                   jake and taylor swift     35
# 9                         taylor and jake     34
# 10       taylor swift and jake gyllenhaal     31
# 11                      taylor swift song     28
# 12                        me taylor swift     27
# 13                     taylor swift songs     21
# 14                     taylor swift album     18
# 15                       taylor swift age     16
# 16       all too well taylor swift lyrics     16
# 17                    all too well lyrics     15
# ...

# %% [markdown]
# Releated searches about Taylor Swift from October 2012, the month of the Red's release.

# %%
kw_list = ["Taylor Swift"]
pytrend.build_payload(kw_list, cat=0, timeframe='2012-10-01 2012-10-31', geo='', gprop='')
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                                                 query  value
# 0                                                 red    100
# 1                                    red taylor swift     96
# 2                                              lyrics     88
# 3                                 taylor swift lyrics     84
# 4                                  taylor swift album     30
# 5                                  taylor swift songs     25
# 6                             lyrics taylor swift red     23
# 7                                trouble taylor swift     23
# 8                                           red album     23
# 9                              taylor swift album red     23
# 10           taylor swift never getting back together     22
# 11                             red taylor swift album     22
# 12                            i knew you were trouble     22
# 13               i knew you were trouble taylor swift     21
# ...

# %% [markdown]
# Releated searches about Red Taylor Swift from November 2021, the month of the Red (Taylor's Version) release.

# %%
kw_list = ["Red Taylor Swift"]
pytrend.build_payload(kw_list, cat=0, timeframe='2021-11-01 2021-11-30', geo='', gprop='')
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                                     query  value
# 0                red taylor swift version    100
# 1                               red album     50
# 2                              red lyrics     49
# 3                  red album taylor swift     43
# 4                            all too well     30
# 5            taylor swift jake gyllenhaal     24
# 6                         jake gyllenhaal     21
# 7           taylor swift red release date     21
# 8                  taylor swift red vinyl     17
# 9                     all too well lyrics     15
# 10                                 red tv     14
# 11                 taylor swift red scarf     13
# 12                    red tv taylor swift     12
# 13                 taylor swift red merch     12
# 14       taylor swift red taylors version     11
# 15              red cardigan taylor swift     10
# 16                    red by taylor swift      6
# 17                 taylor swift red video      6
# ...

# %% [markdown]
# Releated searches about Red Taylor Swift from October 2012, the month of the Red's release.

# %%
kw_list = ["Red Taylor Swift"]
pytrend.build_payload(kw_list, cat=0, timeframe='2012-10-01 2012-10-31', geo='', gprop='')
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                                    query  value
# 0                taylor swift red lyrics    100
# 1                             red lyrics     97
# 2                     taylor swift album     97
# 3                 red taylor swift album     96
# 4                 taylor swift album red     96
# 5                    taylor swift lyrics     95
# 6                              red album     94
# 7                 taylor swift red songs     44
# 8                     taylor swift songs     41
# 9              red taylor swift download     37
# 10          taylor swift red album songs     33
# 11                  red taylor swift mp3     27
# 12            red taylor swift tracklist     23
# 13                         red tracklist     22
# 14       download red album taylor swift     19
# 15              red taylor swift youtube     18
# 16                   red by taylor swift     18
# 17                 taylor swift red tour     16
# ...

# %% [markdown]
# Releated searches about Red (Taylor's Version) from November 2021, the month of the Red (Taylor's Version) release.

# %%
kw_list = ["Red (Taylor's Version)"]
pytrend.build_payload(kw_list, cat=0, timeframe='2021-11-01 2021-11-30', geo='', gprop='')
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                               query  value
# 0  taylor swift red taylors version    100
# 1    red taylors version metacritic     11
# 2        red taylors version review      6, 'rising':                               query  value
# 0    red taylors version metacritic  64900
# 1        red taylors version review  32350
# 2  taylor swift red taylors version    140}])

# %%
red_words = ["red", "taylor", "swift", "red", "taylor", "swift", "lyrics", "taylor", "swift", "album", "taylor", "swift", "we", "are", "never", "red", "lyrics", "taylor", "swift", "never", "getting", "back", "together", "taylor", "swift", "getting", "back", "together", "red", "taylor", "swift", "lyrics", "taylor", "swift", "songs", "taylor", "swift", "album", "red", "we", "are", "never", "getting", "back", "together", "taylor", "swift", "red", "album", "trouble", "taylor", "swift", "we", "are", "never", "getting", "back", "together", "red", "taylor", "swift", "album", "knew", "you", "were", "trouble", "taylor", "swift", "i", "knew", "you", "were", "trouble", "taylor", "swift", "we", "are", "never", "ever", "taylor", "swift", "never", "ever", "getting", "back", "together", "i", "knew", "you", "were", "trouble", "taylor", "swift", "begin", "again", "we", "are", "never", "ever", "getting", "back", "together", "begin", "again", "taylor", "swift", "taylor", "swift"]

# %%
from collections import Counter
from wordcloud import WordCloud 
import matplotlib.pyplot as plt
word_could_dict=Counter(red_words)
wc_red = WordCloud(colormap = 'gist_heat', background_color = 'white', width = 1000, height = 500).generate_from_frequencies(word_could_dict)

plt.figure(figsize=(15,8))
plt.imshow(wc_red)
plt.axis("off")
#plt.show()
plt.savefig('redoriginal.png', bbox_inches='tight')
plt.close()

# %%
tv_words = ["jake", "taylor", "swift", "jake", "gyllenhaal", "taylor", "swift", "jake", "gyllenhaal", "taylor", "swift", "lyrics", "taylor", "swift", "all", "too", "well", "red", "taylor", "swift", "red", "all", "too", "well", "jake", "and", "taylor", "swift", "taylor", "and", "jake", "taylor", "swift", "and", "jake", "gyllenhaal", "taylor", "swift", "song", "me", "taylor", "swift", "taylor", "swift", "songs", "taylor", "swift", "album", "taylor", "swift", "age ", "all", "too", "well", "taylor", "swift", "lyrics", "all", "too", "well", "lyrics", "taylor", "swift", "boyfriend", "taylor", "swift", "i", "bet", "you", "think", "about", "me", "sadie", "sink", "taylor", "swift", "joe", "alwyn", "taylor", "swift", "enchanted", "joe", "alwyn", "enchanted"]

# %%
from collections import Counter
word_could_dict=Counter(tv_words)
wc_red_tv = WordCloud(colormap = 'gist_heat', background_color = 'white', width = 1000, height = 500).generate_from_frequencies(word_could_dict)

plt.figure(figsize=(15,8))
plt.imshow(wc_red_tv)
plt.axis("off")
#plt.show()
plt.savefig('red(taylorversion).png', bbox_inches='tight')
plt.close()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(14, 12))
ax1.set_title("Red")
ax1.imshow(wc_red, interpolation="bilinear")
ax1.axis('off')
ax2.set_title("Red (Taylor's Version)")
ax2.imshow(wc_red_tv, interpolation="bilinear")
ax2.axis('off')
plt.savefig('relatedq.png')
plt.show()
